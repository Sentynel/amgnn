# %%
from fastai.vision import *
from fastai import *

data = ImageDataBunch.from_csv("data/", csv_labels="black_death.csv", size=28)

# %%
data.show_batch(rows=3)

# %%
learn = create_cnn(data, models.resnet18, metrics=accuracy)
learn.fit(3)
# Out:
# Total time: 00:10
# epoch  train_loss  valid_loss  accuracy
# 1      0.919638    0.735677    0.621170  (00:04)
# 2      0.724456    0.660798    0.637883  (00:03)
# 3      0.621188    0.693509    0.635098  (00:03)

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
learn.save("black_death")
