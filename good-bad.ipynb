# %%
from fastai.vision import *
from fastai import *

data = ImageDataBunch.from_csv("data/", csv_labels="good.csv", size=28)

# %%
data.show_batch(rows=3)

# %%
learn = create_cnn(data, models.resnet18, metrics=accuracy)
learn.fit(3)
# Out:
# Total time: 00:08
# epoch  train_loss  valid_loss  accuracy
# 1      1.009290    0.848951    0.503571  (00:02)
# 2      0.808451    0.805602    0.532143  (00:02)
# 3      0.697797    0.794685    0.571429  (00:02)

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
learn.save("good_bad")
